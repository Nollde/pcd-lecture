# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from cycler import cycler

# %%
def plot2d(ll, lr, ul, ur, weights_lr=None):
    d0 = 0
    for d1 in range(1, N_DIMS):
        fig, axs = plt.subplots(2, 2, figsize=(9, 7))
        opts = dict(bins=20, range=[[0, SCALE], [0, SCALE]], density=True)
        axs[1,0].hist2d(ll[:, d0], ll[:, d1], **opts)
        axs[1,1].hist2d(lr[:, d0], lr[:, d1], **opts)
        axs[0,0].hist2d(ul[:, d0], ul[:, d1], **opts)
        h = axs[0,1].hist2d(ur[:, d0], ur[:, d1], weights=weights_lr, **opts)
        fig.colorbar(h[3], ax=axs.flat)
        axs[1,0].set_title("A"), axs[1,1].set_title("B"), axs[0,0].set_title("C"), axs[0,1].set_title("D")
        fig.show()

# %%
N_PEAK = 5
N_DIMS = 2
SCALE = 10

# %%
rng = np.random.default_rng(123)
centers_ac = rng.uniform(0, SCALE, size=(N_PEAK, N_DIMS))
centers_bd = rng.uniform(0, SCALE, size=(N_PEAK, N_DIMS))

# %%
def make_samples(centers, n_samples=1_000_000):
    output = []
    for i, center in enumerate(centers):
        output.append(rng.normal(
            loc=center,
            scale=(SCALE + i) / (1 + i),
            size=(n_samples // N_PEAK, N_DIMS)
        ))
    return np.concatenate(output)

# %%
a = make_samples(centers_ac, 1_000_000)
b = make_samples(centers_bd, 1_000_000)
c = make_samples(centers_ac, 1_000_000)
d = make_samples(centers_bd, 1_000)

# %%
plot2d(a, b, c, d)
# Out:
# /var/folders/dw/z8g0cw_s0nzcv0z1jn7vfgsm0000gn/T/ipykernel_35417/1477348175.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
model = tf.keras.Sequential(
    layers=[
        tf.keras.Input(shape=(N_DIMS,)),
        tf.keras.layers.Dense(256, activation="relu"),
        tf.keras.layers.Dense(256, activation="relu"),
        tf.keras.layers.Dense(256, activation="relu"),
        tf.keras.layers.Dense(1),
    ]
)

# %%
bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
model.compile(optimizer="adam", loss=bce, metrics=["accuracy"])
model.summary()

# %%
x = np.concatenate([a, b])
y = np.concatenate([np.ones(len(a)), np.zeros(len(b))])

# %%
p = np.random.permutation(len(x))
x, y = x[p], y[p]

# %%
model.fit(x=x, y=y, batch_size=1024, epochs=3, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/3
# 1563/1563 - 15s - loss: 0.6582 - accuracy: 0.5841 - val_loss: 0.6557 - val_accuracy: 0.5947
# Epoch 2/3
# 1563/1563 - 15s - loss: 0.6552 - accuracy: 0.5931 - val_loss: 0.6545 - val_accuracy: 0.5927
# Epoch 3/3
# 1563/1563 - 15s - loss: 0.6548 - accuracy: 0.5943 - val_loss: 0.6544 - val_accuracy: 0.5963

# %%
weights_c_to_d = np.exp(-model.predict(c, batch_size=4096)[:, 0])

# %%
plot2d(a, b, c, ur=c, weights_lr=weights_c_to_d)
# Out:
# /var/folders/dw/z8g0cw_s0nzcv0z1jn7vfgsm0000gn/T/ipykernel_35417/1477348175.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# 1-D projections
for d0 in range(N_DIMS):
    fig, axs = plt.subplots(figsize=(10,4))
    for opts in cycler(
        x=[a, b, c, d, c],
        weights=[None] * 4 + [weights_c_to_d],
        label=["A","B","C","D","reweighted"],
        linestyle=["--", "--", ":", ":", "-"],
    ):
        axs.hist(
            opts.pop("x")[:, d0],
            **opts,
            bins=20,
            range=[0, SCALE],
            density=True,
            histtype="step",
            lw=3,
        )
    axs.legend(loc=0)
    fig.show()
